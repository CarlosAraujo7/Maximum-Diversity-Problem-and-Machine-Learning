# %%
import os
import random
import math

# Funções para geração de pesos em escala ajustada
def gerar_pesos_uniformes(n):
    """Gera pesos uniformes em float entre 100 e 200."""
    return {(i, j): round(random.uniform(0, 9), 5) for i in range(n) for j in range(i + 1, n)}

def gerar_pesos_euclidianos(n):
    """Gera pesos baseados em distâncias euclidianas ajustadas entre 100 e 200."""
    coordenadas = {i: (random.uniform(0, 100), random.uniform(0, 100)) for i in range(n)}
    return {
        (i, j): round(100 + math.sqrt((coordenadas[i][0] - coordenadas[j][0])**2 + (coordenadas[i][1] - coordenadas[j][1])**2), 5)
        for i in range(n) for j in range(i + 1, n)
    }

def gerar_pesos_reais_uniformes(n):
    """Gera pesos reais uniformes em float entre 100 e 200."""
    return {(i, j): round(random.uniform(100, 200), 5) for i in range(n) for j in range(i + 1, n)}

# Função para salvar instâncias no formato especificado
def salvar_instancia(nome, n, k, pesos):
    with open(f"{nome}.txt", "w") as f:
        f.write(f"{n} {k}\n")
        for (i, j), peso in sorted(pesos.items()):
            f.write(f"{i} {j} {peso}\n")

# Configuração fixa das instâncias
def configurar_instancias():
    tamanhos = [
        (10, [2, 3]),
        (15, [2, 3, 4, 6]),
        (25, [2, 3, 5, 7]),
        (50, [5, 12, 15]),
        (100, [10, 20, 30, 40]),
        (125, [12, 15, 37]),
        (150, [15, 25, 45]),
        (200, [20, 40, 60, 80]),
        (300, [30, 60, 90, 120]),
        (400, [40, 80, 120, 160]),
        (500, [50, 100, 150, 200])
    ]
    return tamanhos

# Geração de instâncias para cada método
def gerar_instancias_por_grupo(nome_grupo, gerador_pesos):
    tamanhos = configurar_instancias()
    instancia_contador = 1

    if not os.path.exists("instancias"):
        os.makedirs("instancias")

    for n, ks in tamanhos:
        for k in ks:
            for _ in range(5):  # Gerar 5 instâncias por configuração (totalizando 250 por grupo)
                pesos = gerador_pesos(n)
                nome_arquivo = f"instancias/{nome_grupo}-{instancia_contador}_n{n}_m{k}"
                salvar_instancia(nome_arquivo, n, k, pesos)
                print(f"Instância gerada: {nome_arquivo}.txt")
                instancia_contador += 1

def main():
    grupos = {
        "carlos-uniforme": gerar_pesos_uniformes,
        "carlos-euclidiana": gerar_pesos_euclidianos,
        "carlos-real": gerar_pesos_reais_uniformes
    }

    for nome_grupo, gerador in grupos.items():
        gerar_instancias_por_grupo(nome_grupo, gerador)

if __name__ == "__main__":
    main()
# Out:
# Instância gerada: instancias/carlos-uniforme-1_n10_m2.txt
# Instância gerada: instancias/carlos-uniforme-2_n10_m2.txt
# Instância gerada: instancias/carlos-uniforme-3_n10_m2.txt
# Instância gerada: instancias/carlos-uniforme-4_n10_m2.txt
# Instância gerada: instancias/carlos-uniforme-5_n10_m2.txt
# Instância gerada: instancias/carlos-uniforme-6_n10_m3.txt
# Instância gerada: instancias/carlos-uniforme-7_n10_m3.txt
# Instância gerada: instancias/carlos-uniforme-8_n10_m3.txt
# Instância gerada: instancias/carlos-uniforme-9_n10_m3.txt
# Instância gerada: instancias/carlos-uniforme-10_n10_m3.txt
# Instância gerada: instancias/carlos-uniforme-11_n15_m2.txt
# Instância gerada: instancias/carlos-uniforme-12_n15_m2.txt
# Instância gerada: instancias/carlos-uniforme-13_n15_m2.txt
# Instância gerada: instancias/carlos-uniforme-14_n15_m2.txt
# Instância gerada: instancias/carlos-uniforme-15_n15_m2.txt
# Instância gerada: instancias/carlos-uniforme-16_n15_m3.txt
# Instância gerada: instancias/carlos-uniforme-17_n15_m3.txt
# Instância gerada: instancias/carlos-uniforme-18_n15_m3.txt
# Instância gerada: instancias/carlos-uniforme-19_n15_m3.txt
# Instância gerada: instancias/carlos-uniforme-20_n15_m3.txt
# Instância gerada: instancias/carlos-uniforme-21_n15_m4.txt
# Instância gerada: instancias/carlos-uniforme-22_n15_m4.txt
# Instância gerada: instancias/carlos-uniforme-23_n15_m4.txt
# Instância gerada: instancias/carlos-uniforme-24_n15_m4.txt
# Instância gerada: instancias/carlos-uniforme-25_n15_m4.txt
# Instância gerada: instancias/carlos-uniforme-26_n15_m6.txt
# Instância gerada: instancias/carlos-uniforme-27_n15_m6.txt
# Instância gerada: instancias/carlos-uniforme-28_n15_m6.txt
# Instância gerada: instancias/carlos-uniforme-29_n15_m6.txt
# Instância gerada: instancias/carlos-uniforme-30_n15_m6.txt
# Instância gerada: instancias/carlos-uniforme-31_n25_m2.txt
# Instância gerada: instancias/carlos-uniforme-32_n25_m2.txt
# Instância gerada: instancias/carlos-uniforme-33_n25_m2.txt
# Instância gerada: instancias/carlos-uniforme-34_n25_m2.txt
# Instância gerada: instancias/carlos-uniforme-35_n25_m2.txt
# Instância gerada: instancias/carlos-uniforme-36_n25_m3.txt
# Instância gerada: instancias/carlos-uniforme-37_n25_m3.txt
# Instância gerada: instancias/carlos-uniforme-38_n25_m3.txt
# Instância gerada: instancias/carlos-uniforme-39_n25_m3.txt
# Instância gerada: instancias/carlos-uniforme-40_n25_m3.txt
# Instância gerada: instancias/carlos-uniforme-41_n25_m5.txt
# Instância gerada: instancias/carlos-uniforme-42_n25_m5.txt
# Instância gerada: instancias/carlos-uniforme-43_n25_m5.txt
# Instância gerada: instancias/carlos-uniforme-44_n25_m5.txt
# Instância gerada: instancias/carlos-uniforme-45_n25_m5.txt
# Instância gerada: instancias/carlos-uniforme-46_n25_m7.txt
# Instância gerada: instancias/carlos-uniforme-47_n25_m7.txt
# Instância gerada: instancias/carlos-uniforme-48_n25_m7.txt
# Instância gerada: instancias/carlos-uniforme-49_n25_m7.txt
# Instância gerada: instancias/carlos-uniforme-50_n25_m7.txt
# Instância gerada: instancias/carlos-uniforme-51_n50_m5.txt
# Instância gerada: instancias/carlos-uniforme-52_n50_m5.txt
# Instância gerada: instancias/carlos-uniforme-53_n50_m5.txt
# Instância gerada: instancias/carlos-uniforme-54_n50_m5.txt
# Instância gerada: instancias/carlos-uniforme-55_n50_m5.txt
# Instância gerada: instancias/carlos-uniforme-56_n50_m12.txt
# Instância gerada: instancias/carlos-uniforme-57_n50_m12.txt
# Instância gerada: instancias/carlos-uniforme-58_n50_m12.txt
# Instância gerada: instancias/carlos-uniforme-59_n50_m12.txt
# Instância gerada: instancias/carlos-uniforme-60_n50_m12.txt
# Instância gerada: instancias/carlos-uniforme-61_n50_m15.txt
# Instância gerada: instancias/carlos-uniforme-62_n50_m15.txt
# Instância gerada: instancias/carlos-uniforme-63_n50_m15.txt
# Instância gerada: instancias/carlos-uniforme-64_n50_m15.txt
# Instância gerada: instancias/carlos-uniforme-65_n50_m15.txt
# Instância gerada: instancias/carlos-uniforme-66_n100_m10.txt
# Instância gerada: instancias/carlos-uniforme-67_n100_m10.txt
# Instância gerada: instancias/carlos-uniforme-68_n100_m10.txt
# Instância gerada: instancias/carlos-uniforme-69_n100_m10.txt
# Instância gerada: instancias/carlos-uniforme-70_n100_m10.txt
# Instância gerada: instancias/carlos-uniforme-71_n100_m20.txt
# Instância gerada: instancias/carlos-uniforme-72_n100_m20.txt
# Instância gerada: instancias/carlos-uniforme-73_n100_m20.txt
# Instância gerada: instancias/carlos-uniforme-74_n100_m20.txt
# Instância gerada: instancias/carlos-uniforme-75_n100_m20.txt
# Instância gerada: instancias/carlos-uniforme-76_n100_m30.txt
# Instância gerada: instancias/carlos-uniforme-77_n100_m30.txt
# Instância gerada: instancias/carlos-uniforme-78_n100_m30.txt
# Instância gerada: instancias/carlos-uniforme-79_n100_m30.txt
# Instância gerada: instancias/carlos-uniforme-80_n100_m30.txt
# Instância gerada: instancias/carlos-uniforme-81_n100_m40.txt
# Instância gerada: instancias/carlos-uniforme-82_n100_m40.txt
# Instância gerada: instancias/carlos-uniforme-83_n100_m40.txt
# Instância gerada: instancias/carlos-uniforme-84_n100_m40.txt
# Instância gerada: instancias/carlos-uniforme-85_n100_m40.txt
# Instância gerada: instancias/carlos-uniforme-86_n125_m12.txt
# Instância gerada: instancias/carlos-uniforme-87_n125_m12.txt
# Instância gerada: instancias/carlos-uniforme-88_n125_m12.txt
# Instância gerada: instancias/carlos-uniforme-89_n125_m12.txt
# Instância gerada: instancias/carlos-uniforme-90_n125_m12.txt
# Instância gerada: instancias/carlos-uniforme-91_n125_m15.txt
# Instância gerada: instancias/carlos-uniforme-92_n125_m15.txt
# Instância gerada: instancias/carlos-uniforme-93_n125_m15.txt
# Instância gerada: instancias/carlos-uniforme-94_n125_m15.txt
# Instância gerada: instancias/carlos-uniforme-95_n125_m15.txt
# Instância gerada: instancias/carlos-uniforme-96_n125_m37.txt
# Instância gerada: instancias/carlos-uniforme-97_n125_m37.txt
# Instância gerada: instancias/carlos-uniforme-98_n125_m37.txt
# Instância gerada: instancias/carlos-uniforme-99_n125_m37.txt
# Instância gerada: instancias/carlos-uniforme-100_n125_m37.txt
# Instância gerada: instancias/carlos-uniforme-101_n150_m15.txt
# Instância gerada: instancias/carlos-uniforme-102_n150_m15.txt
# Instância gerada: instancias/carlos-uniforme-103_n150_m15.txt
# Instância gerada: instancias/carlos-uniforme-104_n150_m15.txt
# Instância gerada: instancias/carlos-uniforme-105_n150_m15.txt
# Instância gerada: instancias/carlos-uniforme-106_n150_m25.txt
# Instância gerada: instancias/carlos-uniforme-107_n150_m25.txt
# Instância gerada: instancias/carlos-uniforme-108_n150_m25.txt
# Instância gerada: instancias/carlos-uniforme-109_n150_m25.txt
# Instância gerada: instancias/carlos-uniforme-110_n150_m25.txt
# Instância gerada: instancias/carlos-uniforme-111_n150_m45.txt
# Instância gerada: instancias/carlos-uniforme-112_n150_m45.txt
# Instância gerada: instancias/carlos-uniforme-113_n150_m45.txt
# Instância gerada: instancias/carlos-uniforme-114_n150_m45.txt
# Instância gerada: instancias/carlos-uniforme-115_n150_m45.txt
# Instância gerada: instancias/carlos-uniforme-116_n200_m20.txt
# Instância gerada: instancias/carlos-uniforme-117_n200_m20.txt
# Instância gerada: instancias/carlos-uniforme-118_n200_m20.txt
# Instância gerada: instancias/carlos-uniforme-119_n200_m20.txt
# Instância gerada: instancias/carlos-uniforme-120_n200_m20.txt
# Instância gerada: instancias/carlos-uniforme-121_n200_m40.txt
# Instância gerada: instancias/carlos-uniforme-122_n200_m40.txt
# Instância gerada: instancias/carlos-uniforme-123_n200_m40.txt
# Instância gerada: instancias/carlos-uniforme-124_n200_m40.txt
# Instância gerada: instancias/carlos-uniforme-125_n200_m40.txt
# Instância gerada: instancias/carlos-uniforme-126_n200_m60.txt
# Instância gerada: instancias/carlos-uniforme-127_n200_m60.txt
# Instância gerada: instancias/carlos-uniforme-128_n200_m60.txt
# Instância gerada: instancias/carlos-uniforme-129_n200_m60.txt
# Instância gerada: instancias/carlos-uniforme-130_n200_m60.txt
# Instância gerada: instancias/carlos-uniforme-131_n200_m80.txt
# Instância gerada: instancias/carlos-uniforme-132_n200_m80.txt
# Instância gerada: instancias/carlos-uniforme-133_n200_m80.txt
# Instância gerada: instancias/carlos-uniforme-134_n200_m80.txt
# Instância gerada: instancias/carlos-uniforme-135_n200_m80.txt
# Instância gerada: instancias/carlos-uniforme-136_n300_m30.txt
# Instância gerada: instancias/carlos-uniforme-137_n300_m30.txt
# Instância gerada: instancias/carlos-uniforme-138_n300_m30.txt
# Instância gerada: instancias/carlos-uniforme-139_n300_m30.txt
# Instância gerada: instancias/carlos-uniforme-140_n300_m30.txt
# Instância gerada: instancias/carlos-uniforme-141_n300_m60.txt
# Instância gerada: instancias/carlos-uniforme-142_n300_m60.txt
# Instância gerada: instancias/carlos-uniforme-143_n300_m60.txt
# Instância gerada: instancias/carlos-uniforme-144_n300_m60.txt
# Instância gerada: instancias/carlos-uniforme-145_n300_m60.txt
# Instância gerada: instancias/carlos-uniforme-146_n300_m90.txt
# Instância gerada: instancias/carlos-uniforme-147_n300_m90.txt
# Instância gerada: instancias/carlos-uniforme-148_n300_m90.txt
# Instância gerada: instancias/carlos-uniforme-149_n300_m90.txt
# Instância gerada: instancias/carlos-uniforme-150_n300_m90.txt
# Instância gerada: instancias/carlos-uniforme-151_n300_m120.txt
# Instância gerada: instancias/carlos-uniforme-152_n300_m120.txt
# Instância gerada: instancias/carlos-uniforme-153_n300_m120.txt
# Instância gerada: instancias/carlos-uniforme-154_n300_m120.txt
# Instância gerada: instancias/carlos-uniforme-155_n300_m120.txt
# Instância gerada: instancias/carlos-uniforme-156_n400_m40.txt
# Instância gerada: instancias/carlos-uniforme-157_n400_m40.txt
# Instância gerada: instancias/carlos-uniforme-158_n400_m40.txt
# Instância gerada: instancias/carlos-uniforme-159_n400_m40.txt
# Instância gerada: instancias/carlos-uniforme-160_n400_m40.txt
# Instância gerada: instancias/carlos-uniforme-161_n400_m80.txt
# Instância gerada: instancias/carlos-uniforme-162_n400_m80.txt
# Instância gerada: instancias/carlos-uniforme-163_n400_m80.txt
# Instância gerada: instancias/carlos-uniforme-164_n400_m80.txt
# Instância gerada: instancias/carlos-uniforme-165_n400_m80.txt
# Instância gerada: instancias/carlos-uniforme-166_n400_m120.txt
# Instância gerada: instancias/carlos-uniforme-167_n400_m120.txt
# Instância gerada: instancias/carlos-uniforme-168_n400_m120.txt
# Instância gerada: instancias/carlos-uniforme-169_n400_m120.txt
# Instância gerada: instancias/carlos-uniforme-170_n400_m120.txt
# Instância gerada: instancias/carlos-uniforme-171_n400_m160.txt
# Instância gerada: instancias/carlos-uniforme-172_n400_m160.txt
# Instância gerada: instancias/carlos-uniforme-173_n400_m160.txt
# Instância gerada: instancias/carlos-uniforme-174_n400_m160.txt
# Instância gerada: instancias/carlos-uniforme-175_n400_m160.txt
# Instância gerada: instancias/carlos-uniforme-176_n500_m50.txt
# Instância gerada: instancias/carlos-uniforme-177_n500_m50.txt
# Instância gerada: instancias/carlos-uniforme-178_n500_m50.txt
# Instância gerada: instancias/carlos-uniforme-179_n500_m50.txt
# Instância gerada: instancias/carlos-uniforme-180_n500_m50.txt
# Instância gerada: instancias/carlos-uniforme-181_n500_m100.txt
# Instância gerada: instancias/carlos-uniforme-182_n500_m100.txt
# Instância gerada: instancias/carlos-uniforme-183_n500_m100.txt
# Instância gerada: instancias/carlos-uniforme-184_n500_m100.txt
# Instância gerada: instancias/carlos-uniforme-185_n500_m100.txt
# Instância gerada: instancias/carlos-uniforme-186_n500_m150.txt
# Instância gerada: instancias/carlos-uniforme-187_n500_m150.txt
# Instância gerada: instancias/carlos-uniforme-188_n500_m150.txt
# Instância gerada: instancias/carlos-uniforme-189_n500_m150.txt
# Instância gerada: instancias/carlos-uniforme-190_n500_m150.txt
# Instância gerada: instancias/carlos-uniforme-191_n500_m200.txt
# Instância gerada: instancias/carlos-uniforme-192_n500_m200.txt
# Instância gerada: instancias/carlos-uniforme-193_n500_m200.txt
# Instância gerada: instancias/carlos-uniforme-194_n500_m200.txt
# Instância gerada: instancias/carlos-uniforme-195_n500_m200.txt
# Instância gerada: instancias/carlos-euclidiana-1_n10_m2.txt
# Instância gerada: instancias/carlos-euclidiana-2_n10_m2.txt
# Instância gerada: instancias/carlos-euclidiana-3_n10_m2.txt
# Instância gerada: instancias/carlos-euclidiana-4_n10_m2.txt
# Instância gerada: instancias/carlos-euclidiana-5_n10_m2.txt
# Instância gerada: instancias/carlos-euclidiana-6_n10_m3.txt
# Instância gerada: instancias/carlos-euclidiana-7_n10_m3.txt
# Instância gerada: instancias/carlos-euclidiana-8_n10_m3.txt
# Instância gerada: instancias/carlos-euclidiana-9_n10_m3.txt
# Instância gerada: instancias/carlos-euclidiana-10_n10_m3.txt
# Instância gerada: instancias/carlos-euclidiana-11_n15_m2.txt
# Instância gerada: instancias/carlos-euclidiana-12_n15_m2.txt
# Instância gerada: instancias/carlos-euclidiana-13_n15_m2.txt
# Instância gerada: instancias/carlos-euclidiana-14_n15_m2.txt
# Instância gerada: instancias/carlos-euclidiana-15_n15_m2.txt
# Instância gerada: instancias/carlos-euclidiana-16_n15_m3.txt
# Instância gerada: instancias/carlos-euclidiana-17_n15_m3.txt
# Instância gerada: instancias/carlos-euclidiana-18_n15_m3.txt
# Instância gerada: instancias/carlos-euclidiana-19_n15_m3.txt
# Instância gerada: instancias/carlos-euclidiana-20_n15_m3.txt
# Instância gerada: instancias/carlos-euclidiana-21_n15_m4.txt
# Instância gerada: instancias/carlos-euclidiana-22_n15_m4.txt
# Instância gerada: instancias/carlos-euclidiana-23_n15_m4.txt
# Instância gerada: instancias/carlos-euclidiana-24_n15_m4.txt
# Instância gerada: instancias/carlos-euclidiana-25_n15_m4.txt
# Instância gerada: instancias/carlos-euclidiana-26_n15_m6.txt
# Instância gerada: instancias/carlos-euclidiana-27_n15_m6.txt
# Instância gerada: instancias/carlos-euclidiana-28_n15_m6.txt
# Instância gerada: instancias/carlos-euclidiana-29_n15_m6.txt
# Instância gerada: instancias/carlos-euclidiana-30_n15_m6.txt
# Instância gerada: instancias/carlos-euclidiana-31_n25_m2.txt
# Instância gerada: instancias/carlos-euclidiana-32_n25_m2.txt
# Instância gerada: instancias/carlos-euclidiana-33_n25_m2.txt
# Instância gerada: instancias/carlos-euclidiana-34_n25_m2.txt
# Instância gerada: instancias/carlos-euclidiana-35_n25_m2.txt
# Instância gerada: instancias/carlos-euclidiana-36_n25_m3.txt
# Instância gerada: instancias/carlos-euclidiana-37_n25_m3.txt
# Instância gerada: instancias/carlos-euclidiana-38_n25_m3.txt
# Instância gerada: instancias/carlos-euclidiana-39_n25_m3.txt
# Instância gerada: instancias/carlos-euclidiana-40_n25_m3.txt
# Instância gerada: instancias/carlos-euclidiana-41_n25_m5.txt
# Instância gerada: instancias/carlos-euclidiana-42_n25_m5.txt
# Instância gerada: instancias/carlos-euclidiana-43_n25_m5.txt
# Instância gerada: instancias/carlos-euclidiana-44_n25_m5.txt
# Instância gerada: instancias/carlos-euclidiana-45_n25_m5.txt
# Instância gerada: instancias/carlos-euclidiana-46_n25_m7.txt
# Instância gerada: instancias/carlos-euclidiana-47_n25_m7.txt
# Instância gerada: instancias/carlos-euclidiana-48_n25_m7.txt
# Instância gerada: instancias/carlos-euclidiana-49_n25_m7.txt
# Instância gerada: instancias/carlos-euclidiana-50_n25_m7.txt
# Instância gerada: instancias/carlos-euclidiana-51_n50_m5.txt
# Instância gerada: instancias/carlos-euclidiana-52_n50_m5.txt
# Instância gerada: instancias/carlos-euclidiana-53_n50_m5.txt
# Instância gerada: instancias/carlos-euclidiana-54_n50_m5.txt
# Instância gerada: instancias/carlos-euclidiana-55_n50_m5.txt
# Instância gerada: instancias/carlos-euclidiana-56_n50_m12.txt
# Instância gerada: instancias/carlos-euclidiana-57_n50_m12.txt
# Instância gerada: instancias/carlos-euclidiana-58_n50_m12.txt
# Instância gerada: instancias/carlos-euclidiana-59_n50_m12.txt
# Instância gerada: instancias/carlos-euclidiana-60_n50_m12.txt
# Instância gerada: instancias/carlos-euclidiana-61_n50_m15.txt
# Instância gerada: instancias/carlos-euclidiana-62_n50_m15.txt
# Instância gerada: instancias/carlos-euclidiana-63_n50_m15.txt
# Instância gerada: instancias/carlos-euclidiana-64_n50_m15.txt
# Instância gerada: instancias/carlos-euclidiana-65_n50_m15.txt
# Instância gerada: instancias/carlos-euclidiana-66_n100_m10.txt
# Instância gerada: instancias/carlos-euclidiana-67_n100_m10.txt
# Instância gerada: instancias/carlos-euclidiana-68_n100_m10.txt
# Instância gerada: instancias/carlos-euclidiana-69_n100_m10.txt
# Instância gerada: instancias/carlos-euclidiana-70_n100_m10.txt
# Instância gerada: instancias/carlos-euclidiana-71_n100_m20.txt
# Instância gerada: instancias/carlos-euclidiana-72_n100_m20.txt
# Instância gerada: instancias/carlos-euclidiana-73_n100_m20.txt
# Instância gerada: instancias/carlos-euclidiana-74_n100_m20.txt
# Instância gerada: instancias/carlos-euclidiana-75_n100_m20.txt
# Instância gerada: instancias/carlos-euclidiana-76_n100_m30.txt
# Instância gerada: instancias/carlos-euclidiana-77_n100_m30.txt
# Instância gerada: instancias/carlos-euclidiana-78_n100_m30.txt
# Instância gerada: instancias/carlos-euclidiana-79_n100_m30.txt
# Instância gerada: instancias/carlos-euclidiana-80_n100_m30.txt
# Instância gerada: instancias/carlos-euclidiana-81_n100_m40.txt
# Instância gerada: instancias/carlos-euclidiana-82_n100_m40.txt
# Instância gerada: instancias/carlos-euclidiana-83_n100_m40.txt
# Instância gerada: instancias/carlos-euclidiana-84_n100_m40.txt
# Instância gerada: instancias/carlos-euclidiana-85_n100_m40.txt
# Instância gerada: instancias/carlos-euclidiana-86_n125_m12.txt
# Instância gerada: instancias/carlos-euclidiana-87_n125_m12.txt
# Instância gerada: instancias/carlos-euclidiana-88_n125_m12.txt
# Instância gerada: instancias/carlos-euclidiana-89_n125_m12.txt
# Instância gerada: instancias/carlos-euclidiana-90_n125_m12.txt
# Instância gerada: instancias/carlos-euclidiana-91_n125_m15.txt
# Instância gerada: instancias/carlos-euclidiana-92_n125_m15.txt
# Instância gerada: instancias/carlos-euclidiana-93_n125_m15.txt
# Instância gerada: instancias/carlos-euclidiana-94_n125_m15.txt
# Instância gerada: instancias/carlos-euclidiana-95_n125_m15.txt
# Instância gerada: instancias/carlos-euclidiana-96_n125_m37.txt
# Instância gerada: instancias/carlos-euclidiana-97_n125_m37.txt
# Instância gerada: instancias/carlos-euclidiana-98_n125_m37.txt
# Instância gerada: instancias/carlos-euclidiana-99_n125_m37.txt
# Instância gerada: instancias/carlos-euclidiana-100_n125_m37.txt
# Instância gerada: instancias/carlos-euclidiana-101_n150_m15.txt
# Instância gerada: instancias/carlos-euclidiana-102_n150_m15.txt
# Instância gerada: instancias/carlos-euclidiana-103_n150_m15.txt
# Instância gerada: instancias/carlos-euclidiana-104_n150_m15.txt
# Instância gerada: instancias/carlos-euclidiana-105_n150_m15.txt
# Instância gerada: instancias/carlos-euclidiana-106_n150_m25.txt
# Instância gerada: instancias/carlos-euclidiana-107_n150_m25.txt
# Instância gerada: instancias/carlos-euclidiana-108_n150_m25.txt
# Instância gerada: instancias/carlos-euclidiana-109_n150_m25.txt
# Instância gerada: instancias/carlos-euclidiana-110_n150_m25.txt
# Instância gerada: instancias/carlos-euclidiana-111_n150_m45.txt
# Instância gerada: instancias/carlos-euclidiana-112_n150_m45.txt
# Instância gerada: instancias/carlos-euclidiana-113_n150_m45.txt
# Instância gerada: instancias/carlos-euclidiana-114_n150_m45.txt
# Instância gerada: instancias/carlos-euclidiana-115_n150_m45.txt
# Instância gerada: instancias/carlos-euclidiana-116_n200_m20.txt
# Instância gerada: instancias/carlos-euclidiana-117_n200_m20.txt
# Instância gerada: instancias/carlos-euclidiana-118_n200_m20.txt
# Instância gerada: instancias/carlos-euclidiana-119_n200_m20.txt
# Instância gerada: instancias/carlos-euclidiana-120_n200_m20.txt
# Instância gerada: instancias/carlos-euclidiana-121_n200_m40.txt
# Instância gerada: instancias/carlos-euclidiana-122_n200_m40.txt
# Instância gerada: instancias/carlos-euclidiana-123_n200_m40.txt
# Instância gerada: instancias/carlos-euclidiana-124_n200_m40.txt
# Instância gerada: instancias/carlos-euclidiana-125_n200_m40.txt
# Instância gerada: instancias/carlos-euclidiana-126_n200_m60.txt
# Instância gerada: instancias/carlos-euclidiana-127_n200_m60.txt
# Instância gerada: instancias/carlos-euclidiana-128_n200_m60.txt
# Instância gerada: instancias/carlos-euclidiana-129_n200_m60.txt
# Instância gerada: instancias/carlos-euclidiana-130_n200_m60.txt
# Instância gerada: instancias/carlos-euclidiana-131_n200_m80.txt
# Instância gerada: instancias/carlos-euclidiana-132_n200_m80.txt
# Instância gerada: instancias/carlos-euclidiana-133_n200_m80.txt
# Instância gerada: instancias/carlos-euclidiana-134_n200_m80.txt
# Instância gerada: instancias/carlos-euclidiana-135_n200_m80.txt
# Instância gerada: instancias/carlos-euclidiana-136_n300_m30.txt
# Instância gerada: instancias/carlos-euclidiana-137_n300_m30.txt
# Instância gerada: instancias/carlos-euclidiana-138_n300_m30.txt
# Instância gerada: instancias/carlos-euclidiana-139_n300_m30.txt
# Instância gerada: instancias/carlos-euclidiana-140_n300_m30.txt
# Instância gerada: instancias/carlos-euclidiana-141_n300_m60.txt
# Instância gerada: instancias/carlos-euclidiana-142_n300_m60.txt
# Instância gerada: instancias/carlos-euclidiana-143_n300_m60.txt
# Instância gerada: instancias/carlos-euclidiana-144_n300_m60.txt
# Instância gerada: instancias/carlos-euclidiana-145_n300_m60.txt
# Instância gerada: instancias/carlos-euclidiana-146_n300_m90.txt
# Instância gerada: instancias/carlos-euclidiana-147_n300_m90.txt
# Instância gerada: instancias/carlos-euclidiana-148_n300_m90.txt
# Instância gerada: instancias/carlos-euclidiana-149_n300_m90.txt
# Instância gerada: instancias/carlos-euclidiana-150_n300_m90.txt
# Instância gerada: instancias/carlos-euclidiana-151_n300_m120.txt
# Instância gerada: instancias/carlos-euclidiana-152_n300_m120.txt
# Instância gerada: instancias/carlos-euclidiana-153_n300_m120.txt
# Instância gerada: instancias/carlos-euclidiana-154_n300_m120.txt
# Instância gerada: instancias/carlos-euclidiana-155_n300_m120.txt
# Instância gerada: instancias/carlos-euclidiana-156_n400_m40.txt
# Instância gerada: instancias/carlos-euclidiana-157_n400_m40.txt
# Instância gerada: instancias/carlos-euclidiana-158_n400_m40.txt
# Instância gerada: instancias/carlos-euclidiana-159_n400_m40.txt
# Instância gerada: instancias/carlos-euclidiana-160_n400_m40.txt
# Instância gerada: instancias/carlos-euclidiana-161_n400_m80.txt
# Instância gerada: instancias/carlos-euclidiana-162_n400_m80.txt
# Instância gerada: instancias/carlos-euclidiana-163_n400_m80.txt
# Instância gerada: instancias/carlos-euclidiana-164_n400_m80.txt
# Instância gerada: instancias/carlos-euclidiana-165_n400_m80.txt
# Instância gerada: instancias/carlos-euclidiana-166_n400_m120.txt
# Instância gerada: instancias/carlos-euclidiana-167_n400_m120.txt
# Instância gerada: instancias/carlos-euclidiana-168_n400_m120.txt
# Instância gerada: instancias/carlos-euclidiana-169_n400_m120.txt
# Instância gerada: instancias/carlos-euclidiana-170_n400_m120.txt
# Instância gerada: instancias/carlos-euclidiana-171_n400_m160.txt
# Instância gerada: instancias/carlos-euclidiana-172_n400_m160.txt
# Instância gerada: instancias/carlos-euclidiana-173_n400_m160.txt
# Instância gerada: instancias/carlos-euclidiana-174_n400_m160.txt
# Instância gerada: instancias/carlos-euclidiana-175_n400_m160.txt
# Instância gerada: instancias/carlos-euclidiana-176_n500_m50.txt
# Instância gerada: instancias/carlos-euclidiana-177_n500_m50.txt
# Instância gerada: instancias/carlos-euclidiana-178_n500_m50.txt
# Instância gerada: instancias/carlos-euclidiana-179_n500_m50.txt
# Instância gerada: instancias/carlos-euclidiana-180_n500_m50.txt
# Instância gerada: instancias/carlos-euclidiana-181_n500_m100.txt
# Instância gerada: instancias/carlos-euclidiana-182_n500_m100.txt
# Instância gerada: instancias/carlos-euclidiana-183_n500_m100.txt
# Instância gerada: instancias/carlos-euclidiana-184_n500_m100.txt
# Instância gerada: instancias/carlos-euclidiana-185_n500_m100.txt
# Instância gerada: instancias/carlos-euclidiana-186_n500_m150.txt
# Instância gerada: instancias/carlos-euclidiana-187_n500_m150.txt
# Instância gerada: instancias/carlos-euclidiana-188_n500_m150.txt
# Instância gerada: instancias/carlos-euclidiana-189_n500_m150.txt
# Instância gerada: instancias/carlos-euclidiana-190_n500_m150.txt
# Instância gerada: instancias/carlos-euclidiana-191_n500_m200.txt
# Instância gerada: instancias/carlos-euclidiana-192_n500_m200.txt
# Instância gerada: instancias/carlos-euclidiana-193_n500_m200.txt
# Instância gerada: instancias/carlos-euclidiana-194_n500_m200.txt
# Instância gerada: instancias/carlos-euclidiana-195_n500_m200.txt
# Instância gerada: instancias/carlos-real-1_n10_m2.txt
# Instância gerada: instancias/carlos-real-2_n10_m2.txt
# Instância gerada: instancias/carlos-real-3_n10_m2.txt
# Instância gerada: instancias/carlos-real-4_n10_m2.txt
# Instância gerada: instancias/carlos-real-5_n10_m2.txt
# Instância gerada: instancias/carlos-real-6_n10_m3.txt
# Instância gerada: instancias/carlos-real-7_n10_m3.txt
# Instância gerada: instancias/carlos-real-8_n10_m3.txt
# Instância gerada: instancias/carlos-real-9_n10_m3.txt
# Instância gerada: instancias/carlos-real-10_n10_m3.txt
# Instância gerada: instancias/carlos-real-11_n15_m2.txt
# Instância gerada: instancias/carlos-real-12_n15_m2.txt
# Instância gerada: instancias/carlos-real-13_n15_m2.txt
# Instância gerada: instancias/carlos-real-14_n15_m2.txt
# Instância gerada: instancias/carlos-real-15_n15_m2.txt
# Instância gerada: instancias/carlos-real-16_n15_m3.txt
# Instância gerada: instancias/carlos-real-17_n15_m3.txt
# Instância gerada: instancias/carlos-real-18_n15_m3.txt
# Instância gerada: instancias/carlos-real-19_n15_m3.txt
# Instância gerada: instancias/carlos-real-20_n15_m3.txt
# Instância gerada: instancias/carlos-real-21_n15_m4.txt
# Instância gerada: instancias/carlos-real-22_n15_m4.txt
# Instância gerada: instancias/carlos-real-23_n15_m4.txt
# Instância gerada: instancias/carlos-real-24_n15_m4.txt
# Instância gerada: instancias/carlos-real-25_n15_m4.txt
# Instância gerada: instancias/carlos-real-26_n15_m6.txt
# Instância gerada: instancias/carlos-real-27_n15_m6.txt
# Instância gerada: instancias/carlos-real-28_n15_m6.txt
# Instância gerada: instancias/carlos-real-29_n15_m6.txt
# Instância gerada: instancias/carlos-real-30_n15_m6.txt
# Instância gerada: instancias/carlos-real-31_n25_m2.txt
# Instância gerada: instancias/carlos-real-32_n25_m2.txt
# Instância gerada: instancias/carlos-real-33_n25_m2.txt
# Instância gerada: instancias/carlos-real-34_n25_m2.txt
# Instância gerada: instancias/carlos-real-35_n25_m2.txt
# Instância gerada: instancias/carlos-real-36_n25_m3.txt
# Instância gerada: instancias/carlos-real-37_n25_m3.txt
# Instância gerada: instancias/carlos-real-38_n25_m3.txt
# Instância gerada: instancias/carlos-real-39_n25_m3.txt
# Instância gerada: instancias/carlos-real-40_n25_m3.txt
# Instância gerada: instancias/carlos-real-41_n25_m5.txt
# Instância gerada: instancias/carlos-real-42_n25_m5.txt
# Instância gerada: instancias/carlos-real-43_n25_m5.txt
# Instância gerada: instancias/carlos-real-44_n25_m5.txt
# Instância gerada: instancias/carlos-real-45_n25_m5.txt
# Instância gerada: instancias/carlos-real-46_n25_m7.txt
# Instância gerada: instancias/carlos-real-47_n25_m7.txt
# Instância gerada: instancias/carlos-real-48_n25_m7.txt
# Instância gerada: instancias/carlos-real-49_n25_m7.txt
# Instância gerada: instancias/carlos-real-50_n25_m7.txt
# Instância gerada: instancias/carlos-real-51_n50_m5.txt
# Instância gerada: instancias/carlos-real-52_n50_m5.txt
# Instância gerada: instancias/carlos-real-53_n50_m5.txt
# Instância gerada: instancias/carlos-real-54_n50_m5.txt
# Instância gerada: instancias/carlos-real-55_n50_m5.txt
# Instância gerada: instancias/carlos-real-56_n50_m12.txt
# Instância gerada: instancias/carlos-real-57_n50_m12.txt
# Instância gerada: instancias/carlos-real-58_n50_m12.txt
# Instância gerada: instancias/carlos-real-59_n50_m12.txt
# Instância gerada: instancias/carlos-real-60_n50_m12.txt
# Instância gerada: instancias/carlos-real-61_n50_m15.txt
# Instância gerada: instancias/carlos-real-62_n50_m15.txt
# Instância gerada: instancias/carlos-real-63_n50_m15.txt
# Instância gerada: instancias/carlos-real-64_n50_m15.txt
# Instância gerada: instancias/carlos-real-65_n50_m15.txt
# Instância gerada: instancias/carlos-real-66_n100_m10.txt
# Instância gerada: instancias/carlos-real-67_n100_m10.txt
# Instância gerada: instancias/carlos-real-68_n100_m10.txt
# Instância gerada: instancias/carlos-real-69_n100_m10.txt
# Instância gerada: instancias/carlos-real-70_n100_m10.txt
# Instância gerada: instancias/carlos-real-71_n100_m20.txt
# Instância gerada: instancias/carlos-real-72_n100_m20.txt
# Instância gerada: instancias/carlos-real-73_n100_m20.txt
# Instância gerada: instancias/carlos-real-74_n100_m20.txt
# Instância gerada: instancias/carlos-real-75_n100_m20.txt
# Instância gerada: instancias/carlos-real-76_n100_m30.txt
# Instância gerada: instancias/carlos-real-77_n100_m30.txt
# Instância gerada: instancias/carlos-real-78_n100_m30.txt
# Instância gerada: instancias/carlos-real-79_n100_m30.txt
# Instância gerada: instancias/carlos-real-80_n100_m30.txt
# Instância gerada: instancias/carlos-real-81_n100_m40.txt
# Instância gerada: instancias/carlos-real-82_n100_m40.txt
# Instância gerada: instancias/carlos-real-83_n100_m40.txt
# Instância gerada: instancias/carlos-real-84_n100_m40.txt
# Instância gerada: instancias/carlos-real-85_n100_m40.txt
# Instância gerada: instancias/carlos-real-86_n125_m12.txt
# Instância gerada: instancias/carlos-real-87_n125_m12.txt
# Instância gerada: instancias/carlos-real-88_n125_m12.txt
# Instância gerada: instancias/carlos-real-89_n125_m12.txt
# Instância gerada: instancias/carlos-real-90_n125_m12.txt
# Instância gerada: instancias/carlos-real-91_n125_m15.txt
# Instância gerada: instancias/carlos-real-92_n125_m15.txt
# Instância gerada: instancias/carlos-real-93_n125_m15.txt
# Instância gerada: instancias/carlos-real-94_n125_m15.txt
# Instância gerada: instancias/carlos-real-95_n125_m15.txt
# Instância gerada: instancias/carlos-real-96_n125_m37.txt
# Instância gerada: instancias/carlos-real-97_n125_m37.txt
# Instância gerada: instancias/carlos-real-98_n125_m37.txt
# Instância gerada: instancias/carlos-real-99_n125_m37.txt
# Instância gerada: instancias/carlos-real-100_n125_m37.txt
# Instância gerada: instancias/carlos-real-101_n150_m15.txt
# Instância gerada: instancias/carlos-real-102_n150_m15.txt
# Instância gerada: instancias/carlos-real-103_n150_m15.txt
# Instância gerada: instancias/carlos-real-104_n150_m15.txt
# Instância gerada: instancias/carlos-real-105_n150_m15.txt
# Instância gerada: instancias/carlos-real-106_n150_m25.txt
# Instância gerada: instancias/carlos-real-107_n150_m25.txt
# Instância gerada: instancias/carlos-real-108_n150_m25.txt
# Instância gerada: instancias/carlos-real-109_n150_m25.txt
# Instância gerada: instancias/carlos-real-110_n150_m25.txt
# Instância gerada: instancias/carlos-real-111_n150_m45.txt
# Instância gerada: instancias/carlos-real-112_n150_m45.txt
# Instância gerada: instancias/carlos-real-113_n150_m45.txt
# Instância gerada: instancias/carlos-real-114_n150_m45.txt
# Instância gerada: instancias/carlos-real-115_n150_m45.txt
# Instância gerada: instancias/carlos-real-116_n200_m20.txt
# Instância gerada: instancias/carlos-real-117_n200_m20.txt
# Instância gerada: instancias/carlos-real-118_n200_m20.txt
# Instância gerada: instancias/carlos-real-119_n200_m20.txt
# Instância gerada: instancias/carlos-real-120_n200_m20.txt
# Instância gerada: instancias/carlos-real-121_n200_m40.txt
# Instância gerada: instancias/carlos-real-122_n200_m40.txt
# Instância gerada: instancias/carlos-real-123_n200_m40.txt
# Instância gerada: instancias/carlos-real-124_n200_m40.txt
# Instância gerada: instancias/carlos-real-125_n200_m40.txt
# Instância gerada: instancias/carlos-real-126_n200_m60.txt
# Instância gerada: instancias/carlos-real-127_n200_m60.txt
# Instância gerada: instancias/carlos-real-128_n200_m60.txt
# Instância gerada: instancias/carlos-real-129_n200_m60.txt
# Instância gerada: instancias/carlos-real-130_n200_m60.txt
# Instância gerada: instancias/carlos-real-131_n200_m80.txt
# Instância gerada: instancias/carlos-real-132_n200_m80.txt
# Instância gerada: instancias/carlos-real-133_n200_m80.txt
# Instância gerada: instancias/carlos-real-134_n200_m80.txt
# Instância gerada: instancias/carlos-real-135_n200_m80.txt
# Instância gerada: instancias/carlos-real-136_n300_m30.txt
# Instância gerada: instancias/carlos-real-137_n300_m30.txt
# Instância gerada: instancias/carlos-real-138_n300_m30.txt
# Instância gerada: instancias/carlos-real-139_n300_m30.txt
# Instância gerada: instancias/carlos-real-140_n300_m30.txt
# Instância gerada: instancias/carlos-real-141_n300_m60.txt
# Instância gerada: instancias/carlos-real-142_n300_m60.txt
# Instância gerada: instancias/carlos-real-143_n300_m60.txt
# Instância gerada: instancias/carlos-real-144_n300_m60.txt
# Instância gerada: instancias/carlos-real-145_n300_m60.txt
# Instância gerada: instancias/carlos-real-146_n300_m90.txt
# Instância gerada: instancias/carlos-real-147_n300_m90.txt
# Instância gerada: instancias/carlos-real-148_n300_m90.txt
# Instância gerada: instancias/carlos-real-149_n300_m90.txt
# Instância gerada: instancias/carlos-real-150_n300_m90.txt
# Instância gerada: instancias/carlos-real-151_n300_m120.txt
# Instância gerada: instancias/carlos-real-152_n300_m120.txt
# Instância gerada: instancias/carlos-real-153_n300_m120.txt
# Instância gerada: instancias/carlos-real-154_n300_m120.txt
# Instância gerada: instancias/carlos-real-155_n300_m120.txt
# Instância gerada: instancias/carlos-real-156_n400_m40.txt
# Instância gerada: instancias/carlos-real-157_n400_m40.txt
# Instância gerada: instancias/carlos-real-158_n400_m40.txt
# Instância gerada: instancias/carlos-real-159_n400_m40.txt
# Instância gerada: instancias/carlos-real-160_n400_m40.txt
# Instância gerada: instancias/carlos-real-161_n400_m80.txt
# Instância gerada: instancias/carlos-real-162_n400_m80.txt
# Instância gerada: instancias/carlos-real-163_n400_m80.txt
# Instância gerada: instancias/carlos-real-164_n400_m80.txt
# Instância gerada: instancias/carlos-real-165_n400_m80.txt
# Instância gerada: instancias/carlos-real-166_n400_m120.txt
# Instância gerada: instancias/carlos-real-167_n400_m120.txt
# Instância gerada: instancias/carlos-real-168_n400_m120.txt
# Instância gerada: instancias/carlos-real-169_n400_m120.txt
# Instância gerada: instancias/carlos-real-170_n400_m120.txt
# Instância gerada: instancias/carlos-real-171_n400_m160.txt
# Instância gerada: instancias/carlos-real-172_n400_m160.txt
# Instância gerada: instancias/carlos-real-173_n400_m160.txt
# Instância gerada: instancias/carlos-real-174_n400_m160.txt
# Instância gerada: instancias/carlos-real-175_n400_m160.txt
# Instância gerada: instancias/carlos-real-176_n500_m50.txt
# Instância gerada: instancias/carlos-real-177_n500_m50.txt
# Instância gerada: instancias/carlos-real-178_n500_m50.txt
# Instância gerada: instancias/carlos-real-179_n500_m50.txt
# Instância gerada: instancias/carlos-real-180_n500_m50.txt
# Instância gerada: instancias/carlos-real-181_n500_m100.txt
# Instância gerada: instancias/carlos-real-182_n500_m100.txt
# Instância gerada: instancias/carlos-real-183_n500_m100.txt
# Instância gerada: instancias/carlos-real-184_n500_m100.txt
# Instância gerada: instancias/carlos-real-185_n500_m100.txt
# Instância gerada: instancias/carlos-real-186_n500_m150.txt
# Instância gerada: instancias/carlos-real-187_n500_m150.txt
# Instância gerada: instancias/carlos-real-188_n500_m150.txt
# Instância gerada: instancias/carlos-real-189_n500_m150.txt
# Instância gerada: instancias/carlos-real-190_n500_m150.txt
# Instância gerada: instancias/carlos-real-191_n500_m200.txt
# Instância gerada: instancias/carlos-real-192_n500_m200.txt
# Instância gerada: instancias/carlos-real-193_n500_m200.txt
# Instância gerada: instancias/carlos-real-194_n500_m200.txt
# Instância gerada: instancias/carlos-real-195_n500_m200.txt
